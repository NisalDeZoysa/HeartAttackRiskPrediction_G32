# %%
# Importing the pandas library and aliasing it as pd
import pandas as pd

# Reading the dataset from a CSV file into a pandas DataFrame
data = pd.read_csv('heart_attack_prediction_dataset.csv')
data.head() # Displaying the first few rows of the DataFrame to get a quick overview
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
# Generating descriptive statistics for the numeric columns in the DataFrame
# This includes count, mean, std (standard deviation), min, 25th percentile (1st quartile),
# median (50th percentile or 2nd quartile), 75th percentile (3rd quartile), and max

data.describe()
# Out:
#                Age  Cholesterol   Heart Rate     Diabetes  Family History  \
# count  8763.000000  8763.000000  8763.000000  8763.000000     8763.000000
# mean     53.707977   259.877211    75.021682     0.652288        0.492982
# std      21.249509    80.863276    20.550948     0.476271        0.499979
# min      18.000000   120.000000    40.000000     0.000000        0.000000
# 25%      35.000000   192.000000    57.000000     0.000000        0.000000
# 50%      54.000000   259.000000    75.000000     1.000000        0.000000
# 75%      72.000000   330.000000    93.000000     1.000000        1.000000
# max      90.000000   400.000000   110.000000     1.000000        1.000000
#
#            Smoking      Obesity  Alcohol Consumption  Exercise Hours Per Week  \
# count  8763.000000  8763.000000          8763.000000              8763.000000
# mean      0.896839     0.501426             0.598083                10.014284
# ...

# %%
# Displaying concise information about the DataFrame, including the data types and non-null values
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8763 entries, 0 to 8762
# Data columns (total 26 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Patient ID                       8763 non-null   object
#  1   Age                              8763 non-null   int64
#  2   Sex                              8763 non-null   object
#  3   Cholesterol                      8763 non-null   int64
#  4   Blood Pressure                   8763 non-null   object
#  5   Heart Rate                       8763 non-null   int64
#  6   Diabetes                         8763 non-null   int64
#  7   Family History                   8763 non-null   int64
#  8   Smoking                          8763 non-null   int64
#  9   Obesity                          8763 non-null   int64
#  10  Alcohol Consumption              8763 non-null   int64
#  11  Exercise Hours Per Week          8763 non-null   float64
# ...

# %%
#check for the missing values
print(data.isnull().sum())
# Out:
# Patient ID                         0
# Age                                0
# Sex                                0
# Cholesterol                        0
# Blood Pressure                     0
# Heart Rate                         0
# Diabetes                           0
# Family History                     0
# Smoking                            0
# Obesity                            0
# Alcohol Consumption                0
# Exercise Hours Per Week            0
# Diet                               0
# Previous Heart Problems            0
# Medication Use                     0
# Stress Level                       0
# Sedentary Hours Per Day            0
# Income                             0
# BMI                                0
# Triglycerides                      0
# Physical Activity Days Per Week    0
# Sleep Hours Per Day                0
# Country                            0
# Continent                          0
# Hemisphere                         0
# ...

# %%
# Creating a new DataFrame 'ctg_data' with selected columns from the original 'data' DataFrame
# The selected columns are 'Sex', 'Diet', 'Continent', 'Country', and 'Hemisphere'
ctg_data = data[['Sex','Diet','Continent','Country','Hemisphere']]

# %%
# Importing necessary libraries for data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Setting the figure size for the plot
plt.figure(figsize=(8, 7))

# Looping through each column in the 'ctg_data' DataFrame
for i in ctg_data.columns:
    # Counting the occurrences of each unique value in the column
    ctg_num = ctg_data[i].value_counts()
    # Creating a bar plot using seaborn
    chart = sns.barplot(x = ctg_num.index, y = ctg_num)
    for p in chart.patches:
        chart.annotate(format(p.get_height(), '.0f'), 
                     (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'center', 
                     xytext = (0, 10), 
                     textcoords = 'offset points',
                     fontsize=10)
    # Rotating x-axis labels for better readability
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    # Displaying the plot for the current column
    plt.show()

# %%
# Setting the figure size for the heatmap plot
plt.figure(figsize = (19,10))

# Creating a heatmap using seaborn to visualize the correlation matrix of selected columns
sns.heatmap(data[['Age','Heart Rate', 'Diabetes', 'Family History', 'Smoking', 'Obesity',
      'Cholesterol','Alcohol Consumption', 'Exercise Hours Per Week',
     'Previous Heart Problems', 'Medication Use', 'Stress Level',
       'Sedentary Hours Per Day', 'Income', 'BMI', 'Triglycerides',
       'Physical Activity Days Per Week', 'Sleep Hours Per Day','Heart Attack Risk']].corr(), cmap="YlGnBu",
            annot=True)

# cmap="YlGnBu" ; Setting the color map for the heatmap

# %%
# Setting the figure size for the boxplot
plt.figure(figsize= (9,4))

# Creating a boxplot using seaborn to visualize the distribution of 'Cholesterol' across different continents
# The boxplot is grouped by 'Sex', and different colors are assigned to each 'Sex' category
# The 'm' color represents male, and the 'g' color represents female
sns.boxplot(x="Continent", y='Cholesterol', hue="Sex",
             palette=["m", "g"],
            data=data)
sns.despine(offset=10, trim=True) # Removing the spines from the plot for aesthetics

# %%
# Setting the figure size for the boxplot
plt.figure(figsize= (9,4))

# Creating a boxplot using seaborn to visualize the distribution of 'Exercise Hours Per Week' across different continents
# The boxplot is grouped by 'Sex', and different colors are assigned to each 'Sex' category
# The 'b' color represents male, and the 'r' color represents female
sns.boxplot(x="Continent", y='Exercise Hours Per Week',  hue="Sex",
             palette=["b", "r"],
            data=data)
sns.despine(offset=10, trim=True) #hue="smoker",

# %%
# Grouping the data by 'Country' and calculating the mean of the 'BMI' column for each country
# This provides an overview of the average BMI in each country

data.groupby('Country')[['BMI']].mean().sort_values(by = "BMI")
# Out:
#                       BMI
# Country
# Japan           28.291157
# France          28.555747
# Vietnam         28.668896
# Spain           28.712143
# Colombia        28.714773
# New Zealand     28.766462
# Argentina       28.794898
# Thailand        28.819812
# China           28.861312
# India           28.864451
# Brazil          28.902022
# United Kingdom  28.941320
# Italy           29.004572
# Nigeria         29.015281
# Canada          29.052191
# South Africa    29.075771
# Australia       29.080740
# Germany         29.098898
# United States   29.165337
# South Korea     29.458494

# %%
import seaborn as sb
from matplotlib import pyplot as plt

# Creating subplots with 3 rows and 1 column
fig, axes = plt.subplots(nrows=3,ncols=1)

# Setting the figure size
fig.set_size_inches(10, 30)

# Creating a boxplot for 'Cholesterol' distribution across different genders
sb.boxplot(data=data,y="Cholesterol",x="Sex",orient="v",ax=axes[0], palette="Oranges")

# Creating a boxplot for 'Age' distribution across different genders
sb.boxplot(data=data,y="Age",x="Sex",orient="v",ax=axes[1], palette="Oranges")

# Creating a boxplot for 'Exercise Hours Per Week' distribution across different genders
sb.boxplot(data=data,y="Exercise Hours Per Week",x="Sex",orient="v",ax=axes[2], palette="Oranges")

# %%
factor = 3

# Calculating the upper and lower limits based on the mean and standard deviation of 'Age'
upper_lim = data['Age'].mean() + data['Age'].std() * factor
lower_lim = data['Age'].mean() - data['Age'].std() * factor

# Creating a new DataFrame 'data_new' by filtering out rows where 'Age' is beyond the defined limits
data_new = data[(data['Age'] < upper_lim) & (data['Age'] > lower_lim)]

# %%
data_new.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
print(data_new['Cholesterol'].mean()) # Printing the mean of 'Cholesterol' in the filtered data

# Calculating the upper and lower limits based on the mean and standard deviation of 'Cholesterol' in the filtered data
upper_lim = data_new['Cholesterol'].mean() + data_new['Cholesterol'].std() * factor
lower_lim = data_new['Cholesterol'].mean() - data_new['Cholesterol'].std() * factor

# Updating the 'data_new' DataFrame by filtering out rows where 'Cholesterol' is beyond the defined limits
data_new = data_new[(data_new['Cholesterol'] < upper_lim) & (data_new['Cholesterol'] > lower_lim)]
# Out:
# 259.8772110007988

# %%
upper_lim = data_new['Heart Rate'].mean() + data_new['Heart Rate'].std() * factor
lower_lim = data_new['Heart Rate'].mean() - data_new['Heart Rate'].std() * factor

# Updating the 'data_new' DataFrame by filtering out rows where 'Heart Rate' is beyond the defined limits
data_new = data_new[(data_new['Heart Rate'] < upper_lim) & (data_new['Heart Rate'] > lower_lim)]

# %%
print(data_new['Exercise Hours Per Week'].mean())
print(data_new['Exercise Hours Per Week'].std ())
upper_lim = data_new['Exercise Hours Per Week'].mean() + data_new['Exercise Hours Per Week'].std() * factor
lower_lim = data_new['Exercise Hours Per Week'].mean() - data_new['Exercise Hours Per Week'].std() * factor

# Updating the 'data_new' DataFrame by filtering out rows where 'Exercise Hours Per Week' is beyond the defined limits
data_new = data_new[(data_new['Exercise Hours Per Week'] < upper_lim) & (data_new['Exercise Hours Per Week'] > lower_lim)]
# Out:
# 10.014283655214827
# 5.783745486854248

# %%
upper_lim = data_new['Stress Level'].mean() + data_new['Stress Level'].std() * factor
lower_lim = data_new['Stress Level'].mean() - data_new['Stress Level'].std() * factor

# Updating the 'data_new' DataFrame by filtering out rows where 'Stress Level' is beyond the defined limits
data_new = data_new[(data_new['Stress Level'] < upper_lim) & (data_new['Stress Level'] > lower_lim)]

# %%
upper_lim = data_new['Sedentary Hours Per Day'].mean() + data_new['Sedentary Hours Per Day'].std() * factor
lower_lim = data_new['Sedentary Hours Per Day'].mean() - data_new['Sedentary Hours Per Day'].std() * factor

# Updating the 'data_new' DataFrame by filtering out rows where 'Sedentary Hours Per Day' is beyond the defined limits
data_new = data_new[(data_new['Sedentary Hours Per Day'] < upper_lim) & (data_new['Sedentary Hours Per Day'] > lower_lim)]

# %%
upper_lim = data_new['Income'].mean () + data_new['Income'].std () * factor
lower_lim = data_new['Income'].mean () - data_new['Income'].std () * factor

# Updating the 'data_new' DataFrame by filtering out rows where 'Income' is beyond the defined limits
data_new = data_new[(data_new['Income'] < upper_lim) & (data_new['Income'] > lower_lim)]

# %%
upper_lim = data_new['BMI'].mean () + data_new['BMI'].std () * factor
lower_lim = data_new['BMI'].mean () - data_new['BMI'].std () * factor

# Updating the 'data_new' DataFrame by filtering out rows where 'Exercise Hours Per Week' is beyond the defined limits
data_new = data_new[(data_new['BMI'] < upper_lim) & (data_new['BMI'] > lower_lim)]

# %%
upper_lim = data_new['Triglycerides'].mean () + data_new['Triglycerides'].std () * factor
lower_lim = data_new['Triglycerides'].mean () - data_new['Triglycerides'].std () * factor

# Updating the 'data_new' DataFrame by filtering out rows where 'BMI' is beyond the defined limits
data_new = data_new[(data_new['Triglycerides'] < upper_lim) & (data_new['Triglycerides'] > lower_lim)]

# %%
upper_lim = data_new['Physical Activity Days Per Week'].mean () + data_new['Physical Activity Days Per Week'].std () * factor
lower_lim = data_new['Physical Activity Days Per Week'].mean () - data_new['Physical Activity Days Per Week'].std () * factor

data_new = data_new[(data_new['Physical Activity Days Per Week'] < upper_lim) & (data_new['Physical Activity Days Per Week'] > lower_lim)]

# %%
upper_lim = data_new['Sleep Hours Per Day'].mean () + data_new['Sleep Hours Per Day'].std () * factor
lower_lim = data_new['Sleep Hours Per Day'].mean () - data_new['Sleep Hours Per Day'].std () * factor

data_new = data_new[(data_new['Sleep Hours Per Day'] < upper_lim) & (data_new['Sleep Hours Per Day'] > lower_lim)]

# %%
data_new.shape
# Out:
# (8763, 26)

# %%
data_new.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...  Sedentary Hours Per Day  Income  \
# 0               0        1        0  ...                 6.615001  261404
# 1               1        1        1  ...                 4.963459  285768
# 2               0        0        0  ...                 9.463426  235282
# 3               1        1        0  ...                 7.648981  125640
# 4               1        1        1  ...                 1.514821  160555
#
#          BMI  Triglycerides  Physical Activity Days Per Week  \
# ...

# %%
# Splitting the 'Blood Pressure' column into two separate columns: 'BP_Systolic' and 'BP_Diastolic'
data_new[['BP_Systolic', 'BP_Diastolic']] = data_new['Blood Pressure'].str.split('/', expand=True)

# Converting the new columns to numeric values, removing non-numeric characters
# The 'errors='coerce'' argument is used to replace any non-numeric values with NaN
data_new['BP_Systolic'] = pd.to_numeric(data_new['BP_Systolic'], errors='coerce')
data_new['BP_Diastolic'] = pd.to_numeric(data_new['BP_Diastolic'], errors='coerce')

# Displaying the updated DataFrame with the new columns
data_new.head()
# Out:
#   Patient ID  Age     Sex  Cholesterol Blood Pressure  Heart Rate  Diabetes  \
# 0    BMW7812   67    Male          208         158/88          72         0
# 1    CZE1114   21    Male          389         165/93          98         1
# 2    BNI9906   21  Female          324         174/99          72         1
# 3    JLN3497   84    Male          383        163/100          73         1
# 4    GFO8847   66    Male          318          91/88          93         1
#
#    Family History  Smoking  Obesity  ...        BMI  Triglycerides  \
# 0               0        1        0  ...  31.251233            286
# 1               1        1        1  ...  27.194973            235
# 2               0        0        0  ...  28.176571            587
# 3               1        1        0  ...  36.464704            378
# 4               1        1        1  ...  21.809144            231
#
#   Physical Activity Days Per Week  Sleep Hours Per Day    Country  \
# ...

# %%
data_new = data_new.drop('Blood Pressure', axis=1) # Dropping the 'Blood Pressure' column from the DataFrame
data_new = data_new.drop('Patient ID', axis=1) # Dropping the 'Patient ID' column from the DataFrame
data_new.head()
# Out:
#    Age     Sex  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0   67    Male          208          72         0               0        1
# 1   21    Male          389          98         1               1        1
# 2   21  Female          324          72         1               0        0
# 3   84    Male          383          73         1               1        1
# 4   66    Male          318          93         1               1        1
#
#    Obesity  Alcohol Consumption  Exercise Hours Per Week  ...        BMI  \
# 0        0                    0                 4.168189  ...  31.251233
# 1        1                    1                 1.813242  ...  27.194973
# 2        0                    0                 2.078353  ...  28.176571
# 3        0                    1                 9.828130  ...  36.464704
# 4        1                    0                 5.804299  ...  21.809144
#
#    Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# ...

# %%
# Displaying the data types of each column in the updated DataFrame
data_new.dtypes
# Out:
# Age                                  int64
# Sex                                 object
# Cholesterol                          int64
# Heart Rate                           int64
# Diabetes                             int64
# Family History                       int64
# Smoking                              int64
# Obesity                              int64
# Alcohol Consumption                  int64
# Exercise Hours Per Week            float64
# Diet                                object
# Previous Heart Problems              int64
# Medication Use                       int64
# Stress Level                         int64
# Sedentary Hours Per Day            float64
# Income                               int64
# BMI                                float64
# Triglycerides                        int64
# Physical Activity Days Per Week      int64
# Sleep Hours Per Day                  int64
# Country                             object
# Continent                           object
# ...

# %%
data_new["Sex"] = data_new["Sex"].astype('category') # Converting the 'Sex' column to the 'category' data type
data_new["Diet"] = data_new["Diet"].astype('category') # Converting the 'Diet' column to the 'category' data type
data_new["Country"] = data_new["Country"].astype('category') # Converting the 'Country' column to the 'category' data type
data_new["Continent"] = data_new["Continent"].astype('category') # Converting the 'Continent' column to the 'category' data type
data_new["Hemisphere"] = data_new["Hemisphere"].astype('category') # Converting the 'Hemisphere' column to the 'category' data type

# %%
data_new.dtypes
# Out:
# Age                                   int64
# Sex                                category
# Cholesterol                           int64
# Heart Rate                            int64
# Diabetes                              int64
# Family History                        int64
# Smoking                               int64
# Obesity                               int64
# Alcohol Consumption                   int64
# Exercise Hours Per Week             float64
# Diet                               category
# Previous Heart Problems               int64
# Medication Use                        int64
# Stress Level                          int64
# Sedentary Hours Per Day             float64
# Income                                int64
# BMI                                 float64
# Triglycerides                         int64
# Physical Activity Days Per Week       int64
# Sleep Hours Per Day                   int64
# Country                            category
# ...

# %%
data_new.head()
# Out:
#    Age     Sex  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  \
# 0   67    Male          208          72         0               0        1
# 1   21    Male          389          98         1               1        1
# 2   21  Female          324          72         1               0        0
# 3   84    Male          383          73         1               1        1
# 4   66    Male          318          93         1               1        1
#
#    Obesity  Alcohol Consumption  Exercise Hours Per Week  ...        BMI  \
# 0        0                    0                 4.168189  ...  31.251233
# 1        1                    1                 1.813242  ...  27.194973
# 2        0                    0                 2.078353  ...  28.176571
# 3        0                    1                 9.828130  ...  36.464704
# 4        1                    0                 5.804299  ...  21.809144
#
#    Triglycerides  Physical Activity Days Per Week  Sleep Hours Per Day  \
# ...

# %%
# Specify the columns you want to include in the new variable
selected_columns = ['Sex', 'Diet', 'Country', 'Continent', 'Hemisphere']

# Create a new variable 'categorical_data' with the selected columns without modifying the original data
categorical_data = data_new[selected_columns].copy()

categorical_data.head()
# Out:
#       Sex       Diet    Country      Continent           Hemisphere
# 0    Male    Average  Argentina  South America  Southern Hemisphere
# 1    Male  Unhealthy     Canada  North America  Northern Hemisphere
# 2  Female    Healthy     France         Europe  Northern Hemisphere
# 3    Male    Average     Canada  North America  Northern Hemisphere
# 4    Male  Unhealthy   Thailand           Asia  Northern Hemisphere

# %%
categorical_data["Sex"] = categorical_data["Sex"].cat.codes # Converting the 'Sex' column to numerical codes
categorical_data["Diet"] = categorical_data["Diet"].cat.codes # Converting the 'Diet' column to numerical codes
categorical_data["Country"] = categorical_data["Country"].cat.codes # Converting the 'Country' column to numerical codes
categorical_data["Continent"] = categorical_data["Continent"].cat.codes # Converting the 'Continent' column to numerical codes
categorical_data["Hemisphere"] = categorical_data["Hemisphere"].cat.codes # Converting the 'Hemisphere' column to numerical codes

# Displaying the updated DataFrame after converting categorical columns to numerical codes
categorical_data.head()
# Out:
#    Sex  Diet  Country  Continent  Hemisphere
# 0    1     0        0          5           1
# 1    1     2        3          4           0
# 2    0     1        6          3           0
# 3    1     0        3          4           0
# 4    1     2       16          1           0

# %%
# Select numerical columns
numerical_data = data_new.select_dtypes(include=['int64', 'float64']).copy()

# Display the numerical data
numerical_data.head()
# Out:
#    Age  Cholesterol  Heart Rate  Diabetes  Family History  Smoking  Obesity  \
# 0   67          208          72         0               0        1        0
# 1   21          389          98         1               1        1        1
# 2   21          324          72         1               0        0        0
# 3   84          383          73         1               1        1        0
# 4   66          318          93         1               1        1        1
#
#    Alcohol Consumption  Exercise Hours Per Week  Previous Heart Problems  ...  \
# 0                    0                 4.168189                        0  ...
# 1                    1                 1.813242                        1  ...
# 2                    0                 2.078353                        1  ...
# 3                    1                 9.828130                        1  ...
# 4                    0                 5.804299                        1  ...
#
# ...

# %%
# Combining the categorical and numerical DataFrames using the 'join' method
dataset_new=categorical_data.join(numerical_data)
dataset_new
# Out:
#       Sex  Diet  Country  Continent  Hemisphere  Age  Cholesterol  Heart Rate  \
# 0       1     0        0          5           1   67          208          72
# 1       1     2        3          4           0   21          389          98
# 2       0     1        6          3           0   21          324          72
# 3       1     0        3          4           0   84          383          73
# 4       1     2       16          1           0   66          318          93
# ...   ...   ...      ...        ...         ...  ...          ...         ...
# 8758    1     1       16          1           0   60          121          61
# 8759    0     1        3          4           0   28          120          73
# 8760    1     0        2          5           1   47          250         105
# 8761    1     2        2          5           1   36          178          60
# 8762    0     1       17          3           0   25          356          75
#
# ...

# %%
print(dataset_new.dtypes)
# Out:
# Sex                                   int8
# Diet                                  int8
# Country                               int8
# Continent                             int8
# Hemisphere                            int8
# Age                                  int64
# Cholesterol                          int64
# Heart Rate                           int64
# Diabetes                             int64
# Family History                       int64
# Smoking                              int64
# Obesity                              int64
# Alcohol Consumption                  int64
# Exercise Hours Per Week            float64
# Previous Heart Problems              int64
# Medication Use                       int64
# Stress Level                         int64
# Sedentary Hours Per Day            float64
# Income                               int64
# BMI                                float64
# Triglycerides                        int64
# Physical Activity Days Per Week      int64
# ...

# %%
import numpy as np

dataset = dataset_new.values # Converting the combined DataFrame 'dataset_new' to a NumPy array

# Extracting features (data_1) and target variable (target_1) from the dataset
data_1 = dataset[:, :23]
target_1 = dataset[:, 23]

# Extracting additional columns 'data_2' and 'data_3' from the dataset
data_2 = dataset[:, 24]
data_3 = dataset[:, 25]

# If you want to keep data_2 and data_3 as separate columns in a 2D array
data_2 = data_2.reshape(-1, 1)
data_3 = data_3.reshape(-1, 1)

# concatenate data_2 and data_3 horizontally to data_1
data_1 = np.concatenate((data_1, data_2, data_3), axis=1)
data_1
# Out:
# array([[  1.,   0.,   0., ...,   6., 158.,  88.],
#        [  1.,   2.,   3., ...,   7., 165.,  93.],
#        [  0.,   1.,   6., ...,   4., 174.,  99.],
#        ...,
#        [  1.,   0.,   2., ...,   4., 161.,  75.],
#        [  1.,   2.,   2., ...,   8., 119.,  67.],
#        [  0.,   1.,  17., ...,   4., 138.,  67.]])

# %%
data_1.shape
# Out:
# (8763, 25)

# %%
target_1.shape
# Out:
# (8763,)

# %%
from sklearn.model_selection import train_test_split

# Splitting the data into training and testing sets
# - 'data_1' is the feature array
# - 'target_1' is the target variable
# - 'test_size=0.3' specifies that 30% of the data will be used for testing
# - 'random_state=0' sets a seed for reproducibility
# - 'stratify=target_1' ensures that the target variable's class distribution is preserved in the splits

train_data,test_data,train_target,test_target=train_test_split(data_1,target_1,test_size=0.3, random_state = 0,stratify=target_1)

# %%
#from sklearn.preprocessing import StandardScaler
#sc = StandardScaler()
#train_data = sc.fit_transform(train_data)
#test_data = sc.transform(test_data)

#from sklearn.preprocessing import StandardScaler

#scaler = StandardScaler()
#train_data_scaled = scaler.fit_transform(train_data)
#test_data_scaled = scaler.fit_transform(test_data)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import cross_val_score

from sklearn.svm import SVC
from sklearn.metrics import precision_score

# %%
from sklearn.svm import SVC

# Creating a Support Vector Machine (SVM) classifier with an RBF kernel
model=SVC(kernel = 'rbf')

# %%
model.fit(train_data,train_target)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='rbf',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
# Making predictions on the test data using the trained Support Vector Machine (SVM) model
predicted_target=model.predict(test_data)

# Importing the accuracy_score function from scikit-learn to evaluate model performance
from sklearn.metrics import accuracy_score

# Calculating the accuracy score by comparing predicted labels with actual labels
acc=accuracy_score(test_target,predicted_target)

print('Accuracy:',acc)
# Out:
# Accuracy: 0.6416888550779765

# %%
from sklearn.metrics import precision_score

# Calculating precision by comparing predicted labels with actual labels
# The 'zero_division' parameter is set to 1 to handle the case where there are no true positive predictions
precision = precision_score(test_target,predicted_target,zero_division=1)

print('Precision of ',precision)
# Out:
# Precision of  1.0

# %%
from sklearn.metrics import confusion_matrix

# Assuming you have your test data and true labels in test_target
# and the predicted labels in predicted_target

# Generate confusion matrix
conf_matrix = confusion_matrix(test_target, predicted_target)

# Print the confusion matrix
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[1687    0]
#  [ 942    0]]

# %%
#sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Reds')
#plt.xlabel('Predicted')
#plt.ylabel('Actual')
#plt.title('Confusion Matrix')
#plt.show()

# %%
model_LGR = LogisticRegression()

# %%
model_LGR.fit(train_data,train_target)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=100,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
predicted_target_LGR=model_LGR.predict(test_data)

from sklearn.metrics import accuracy_score

acc=accuracy_score(test_target,predicted_target_LGR)
print('Accuracy:',acc)
# Out:
# Accuracy: 0.6416888550779765

# %%
from sklearn.metrics import precision_score
precision_LGR = precision_score(test_target,predicted_target_LGR,zero_division=1)
print('Precision of Logistic Regression',precision)
# Out:
# Precision of Logistic Regression 1.0
